# %%
import pandas as pd

# %% [markdown]
# ### Importing Dataset

# %%
data=pd.read_csv("C://Users/Harvy/Downloads/bank-additional-full.csv/bank-additional-full.csv",sep=';')
data.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon ...         1    999         0  nonexistent          1.1
# 1   may         mon ...         1    999         0  nonexistent          1.1
# 2   may         mon ...         1    999         0  nonexistent          1.1
# 3   may         mon ...         1    999         0  nonexistent          1.1
# 4   may         mon ...         1    999         0  nonexistent          1.1
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# ...

# %% [markdown]
# ### Converting categorical string data to numeric

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
print(data['job'].unique())
print(data['marital'].unique())
print(data['education'].unique())
print(data['contact'].unique())
print(data['day_of_week'].unique())
# Out:
# ['housemaid' 'services' 'admin.' 'blue-collar' 'technician' 'retired'
#  'management' 'unemployed' 'self-employed' 'unknown' 'entrepreneur'
#  'student']
# ['married' 'single' 'divorced' 'unknown']
# ['basic.4y' 'high.school' 'basic.6y' 'basic.9y' 'professional.course'
#  'unknown' 'university.degree' 'illiterate']
# ['telephone' 'cellular']
# ['mon' 'tue' 'wed' 'thu' 'fri']

# %%
# Label Encoder converts n types into numbers from 0...n-1
data['job']=le.fit_transform(data['job'])
data['marital']=le.fit_transform(data['marital'])
data['education']=le.fit_transform(data['education'])
data['contact']=le.fit_transform(data['contact'])
data['day_of_week']=le.fit_transform(data['day_of_week'])
data['default']=le.fit_transform(data['default'])
data['housing']=le.fit_transform(data['housing'])
data['loan']=le.fit_transform(data['loan'])
data['month']=le.fit_transform(data['month'])
data['poutcome']=le.fit_transform(data['poutcome'])
data['y']=le.fit_transform(data['y'])

# %%
data.head(10)
# Out:
#    age  job  marital  education  default  housing  loan  contact  month  \
# 0   56    3        1          0        0        0     0        1      6
# 1   57    7        1          3        1        0     0        1      6
# 2   37    7        1          3        0        2     0        1      6
# 3   40    0        1          1        0        0     0        1      6
# 4   56    7        1          3        0        0     2        1      6
# 5   45    7        1          2        1        0     0        1      6
# 6   59    0        1          5        0        0     0        1      6
# 7   41    1        1          7        1        0     0        1      6
# 8   24    9        2          5        0        2     0        1      6
# 9   25    7        2          3        0        2     0        1      6
#
#    day_of_week ...  campaign  pdays  previous  poutcome  emp.var.rate  \
# 0            1 ...         1    999         0         1           1.1
# ...

# %%
data.isnull().any()
# Out:
# age               False
# job               False
# marital           False
# education         False
# default           False
# housing           False
# loan              False
# contact           False
# month             False
# day_of_week       False
# duration          False
# campaign          False
# pdays             False
# previous          False
# poutcome          False
# emp.var.rate      False
# cons.price.idx    False
# cons.conf.idx     False
# euribor3m         False
# nr.employed       False
# y                 False
# dtype: bool

# %% [markdown]
# ### Scaling values of the features 'Age' and 'Duration'

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler(feature_range=(1,8))

# %%
data['age']=scaler.fit_transform(data[['age']])
data.head(20)
# Out:
# C:\Users\Harvy\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:323: DataConversionWarning: Data with input dtype int64 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)
#          age  job  marital  education  default  housing  loan  contact  month  \
# 0   4.370370    3        1          0        0        0     0        1      6
# 1   4.456790    7        1          3        1        0     0        1      6
# 2   2.728395    7        1          3        0        2     0        1      6
# 3   2.987654    0        1          1        0        0     0        1      6
# 4   4.370370    7        1          3        0        0     2        1      6
# 5   3.419753    7        1          2        1        0     0        1      6
# 6   4.629630    0        1          5        0        0     0        1      6
# 7   3.074074    1        1          7        1        0     0        1      6
# ...

# %%
data.corr()
# Out:
#                      age       job   marital  education   default   housing  \
# age             1.000000  0.001250 -0.389753  -0.117892  0.164965 -0.001603
# job             0.001250  1.000000  0.027897   0.134121 -0.028277  0.006962
# marital        -0.389753  0.027897  1.000000   0.109220 -0.079450  0.010467
# education      -0.117892  0.134121  0.109220   1.000000 -0.186859  0.016825
# default         0.164965 -0.028277 -0.079450  -0.186859  1.000000 -0.015815
# housing        -0.001603  0.006962  0.010467   0.016825 -0.015815  1.000000
# loan           -0.007368 -0.010209  0.005788   0.006384 -0.003782  0.044296
# contact         0.007021 -0.025132 -0.054501  -0.105726  0.135238 -0.082186
# month          -0.024877 -0.033213 -0.007629  -0.082684 -0.015830 -0.018141
# day_of_week    -0.017572 -0.000844  0.002202  -0.017986 -0.008701  0.003339
# duration       -0.000866 -0.006490  0.010290  -0.015102 -0.011794 -0.007658
# ...

# %% [markdown]
# From the correlation matrix we can infer that only duration and pdays have significant enough correlation with 'y'

# %%
features=['duration','pdays','previous','emp.var.rate','euribor3m','nr.employed']
X=data[features]
Y=data.y

# %%
import seaborn as sns

# %%
sns.boxplot(x="y",y="duration",data=data)

# %% [markdown]
# ### Calculating Threshold for a good split

# %%
data['duration'].describe()
# Out:
# count    41188.000000
# mean       258.285010
# std        259.279249
# min          0.000000
# 25%        102.000000
# 50%        180.000000
# 75%        319.000000
# max       4918.000000
# Name: duration, dtype: float64

# %%
data_temp=data.loc[data['y']==1]
data_temp['duration'].describe()
# Out:
# count    4640.000000
# mean      553.191164
# std       401.171871
# min        37.000000
# 25%       253.000000
# 50%       449.000000
# 75%       741.250000
# max      4199.000000
# Name: duration, dtype: float64

# %%
import matplotlib.pyplot as plt
plt.hist(data_temp['duration'],label='duration')
# Out:
# (array([2.338e+03, 1.463e+03, 5.900e+02, 1.780e+02, 4.500e+01, 1.400e+01,
#         6.000e+00, 3.000e+00, 2.000e+00, 1.000e+00]),
#  array([  37. ,  453.2,  869.4, 1285.6, 1701.8, 2118. , 2534.2, 2950.4,
#         3366.6, 3782.8, 4199. ]),
#  <a list of 10 Patch objects>)

# %%
data_temp['duration'].describe()
# Out:
# count    4640.000000
# mean      553.191164
# std       401.171871
# min        37.000000
# 25%       253.000000
# 50%       449.000000
# 75%       741.250000
# max      4199.000000
# Name: duration, dtype: float64

# %%
print(data.shape)
check=data.loc[data['y']==1].shape
print(check)
# Out:
# (41188, 21)
# (4640, 21)

# %%
threshold_cand=[50,100,150,200,250,300,350,400,450,500,550]
pos_max=0
neg_max=0
diff=0
threshold=0
for i in threshold_cand:
        temp=data.loc[data['duration']>=i]
        pos=temp.loc[temp['y']==1].shape[0]
        neg=temp.loc[temp['y']==0].shape[0]
        if(((pos/4640)*100>(neg/36548)*100) & ((pos/4640)*100-(neg/36548)*100>diff)):
            pos_max=(pos/4640)*100
            neg_max=(neg/36548)*100
            diff=pos_max-neg_max
            threshold=i
print(threshold)
print(pos_max)
print(neg_max)
# Out:
# 250
# 75.94827586206897
# 29.54197220094123

# %% [markdown]
# Thus we can see that if the duration of call was more than 250 seconds, the chances of being positive are around 76%

# %% [markdown]
# We should target customers and have a call of duration at least 250 seconds.
